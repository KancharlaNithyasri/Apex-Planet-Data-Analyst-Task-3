# %%
import pandas as pd
import datetime as dt


df = pd.read_csv(r"C:\Users\nithish\OneDrive\Documents\Task3(Apex)\Sample - Superstore.csv")

# Convert Order Date to datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'])

# Find the latest date in the dataset to act as our "current day" baseline
snapshot_date = df['Order Date'].max() + dt.timedelta(days=1)
print(f"Analysis Snapshot Date: {snapshot_date}")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[3], line 5
#       1 import pandas as pd
#       2 import datetime as dt
#       3
#       4 # Load the dataset
# ----> 5 df = pd.read_csv(r"C:\Users\nithish\OneDrive\Documents\Task3(Apex)\Sample - Superstore.csv")
#       6
#       7 # Convert Order Date to datetime format
#       8 df['Order Date'] = pd.to_datetime(df['Order Date'])
#
# ...
